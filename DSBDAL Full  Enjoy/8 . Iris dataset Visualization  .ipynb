# %%
"""
8. Visualize the data using Python libraries matplotlib,seaborn by plotting the 
following graphs on iris dataset.
a. Bar-chart
b. Histogram
c. Pie-Chart
d. Scatter-Plot
e. Box-Plot for different features in dataset.
f. Compare different groups in given dataset

"""
# Out:
# '\n8. Visualize the data using Python libraries matplotlib,seaborn by plotting the \nfollowing graphs on iris dataset.\na. Bar-chart\nb. Histogram\nc. Pie-Chart\nd. Scatter-Plot\ne. Box-Plot for different features in dataset.\nf. Compare different groups in given dataset\n\n'

# %%
import pandas as  pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.shape
# Out:
# (150, 6)

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#Histogram
df['SepalLengthCm'].plot(kind='hist')
plt.xlabel("Sepal_length_cm")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sns.pairplot(df)

# %%
#scatterplot
sns.scatterplot(x=df['SepalLengthCm'],y=df["SepalWidthCm"])
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
#Boxplot

# %%
sns.boxplot(df['SepalLengthCm'])
# Out:
# c:\users\harshsk\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SepalLengthCm'>

# %%
df.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
#pie chart 
df['PetalLengthCm'].value_counts()[:5].plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='PetalLengthCm'>

# %%
#Compare different groups in given dataset

# %%
sns.scatterplot(x=df['SepalLengthCm'],y=df['PetalLengthCm'])
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
df["Species"]=df['Species'].replace({"Iris-setosa":1,"Iris-versicolor":2,"Iris-virginica":3})

# %%
plt.bar("Species","SepalLengthCm")
# Out:
# <BarContainer object of 1 artists>

# %%
#new

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        1
# 1   2            4.9           3.0            1.4           0.2        1
# 2   3            4.7           3.2            1.3           0.2        1
# 3   4            4.6           3.1            1.5           0.2        1
# 4   5            5.0           3.6            1.4           0.2        1
