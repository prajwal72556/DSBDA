# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("AirQualityodisha.csv")

# %%
df.head()
# Out:
#    Stn Code Sampling Date   State     City Location of Monitoring Station  \
# 0        68      02-01-15  Odisha  Talcher        T.T.P.S.Colony, Talcher
# 1        68      06-01-15  Odisha  Talcher        T.T.P.S.Colony, Talcher
# 2        68      09-01-15  Odisha  Talcher        T.T.P.S.Colony, Talcher
# 3        68      13-01-15  Odisha  Talcher        T.T.P.S.Colony, Talcher
# 4        68      16-01-15  Odisha  Talcher        T.T.P.S.Colony, Talcher
#
#                                  Agency Type of Location  SO2  NO2  RSPM/PM10  \
# 0  Odisha State Pollution Control Board  Industrial Area   11   24        143
# 1  Odisha State Pollution Control Board  Industrial Area   10   23        133
# 2  Odisha State Pollution Control Board  Industrial Area    8   25        125
# 3  Odisha State Pollution Control Board  Industrial Area   10   25        137
# 4  Odisha State Pollution Control Board  Industrial Area    9   26        186
#
#    PM 2.5
# 0   102.0
# 1    96.0
# 2   116.0
# 3   107.0
# 4   118.0

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
#df['State'].replace({"Oddisha":1})

# %%
df['City'].value_counts()
# Out:
# Bhubaneswar      358
# Kalinga Nagar    306
# Rourkela         296
# Cuttack          277
# Angul            210
# Rayagada         208
# Balasore         200
# Talcher          104
# Paradeep          96
# Berhampur         87
# Konark            78
# Keonjhar          76
# Puri              58
# Sambalpur         38
# Name: City, dtype: int64

# %%
ohe=OneHotEncoder(drop='first')

# %%
State=ohe.fit_transform(df[['State']]).toarray()

# %%
state_encoded=pd.DataFrame(State)

# %%
df=df.drop(columns=['State'])

# %%
new_df=np.hstack((df.values,state_encoded))

# %%
new_df
# Out:
# array([[68, '02-01-15', 'Talcher', ..., 24, 143, 102.0],
#        [68, '06-01-15', 'Talcher', ..., 23, 133, 96.0],
#        [68, '09-01-15', 'Talcher', ..., 25, 125, 116.0],
#        ...,
#        [819, '22-12-15', 'Kalinga Nagar', ..., 10, 90, 38.0],
#        [819, '26-12-15', 'Kalinga Nagar', ..., 10, 97, 39.0],
#        [819, '29-12-15', 'Kalinga Nagar', ..., 10, 98, 39.0]],
#       dtype=object)

# %%
df=pd.DataFrame(new_df)

# %%
df
# Out:
#         0         1              2                           3  \
# 0      68  02-01-15        Talcher     T.T.P.S.Colony, Talcher
# 1      68  06-01-15        Talcher     T.T.P.S.Colony, Talcher
# 2      68  09-01-15        Talcher     T.T.P.S.Colony, Talcher
# 3      68  13-01-15        Talcher     T.T.P.S.Colony, Talcher
# 4      68  16-01-15        Talcher     T.T.P.S.Colony, Talcher
# ...   ...       ...            ...                         ...
# 2387  819  15-12-15  Kalinga Nagar  Roof of RO OFFICE BUILDING
# 2388  819  17-12-15  Kalinga Nagar  Roof of RO OFFICE BUILDING
# 2389  819  22-12-15  Kalinga Nagar  Roof of RO OFFICE BUILDING
# 2390  819  26-12-15  Kalinga Nagar  Roof of RO OFFICE BUILDING
# 2391  819  29-12-15  Kalinga Nagar  Roof of RO OFFICE BUILDING
#
#                                          4                5   6   7    8  \
# 0     Odisha State Pollution Control Board  Industrial Area  11  24  143
# 1     Odisha State Pollution Control Board  Industrial Area  10  23  133
# 2     Odisha State Pollution Control Board  Industrial Area   8  25  125
# 3     Odisha State Pollution Control Board  Industrial Area  10  25  137
# 4     Odisha State Pollution Control Board  Industrial Area   9  26  186
# ...                                    ...              ...  ..  ..  ...
# 2387  Odisha State Pollution Control Board  Industrial Area   2  10   92
# 2388  Odisha State Pollution Control Board  Industrial Area   2  10   99
# 2389  Odisha State Pollution Control Board  Industrial Area   2  10   90
# 2390  Odisha State Pollution Control Board  Industrial Area   2  10   97
# 2391  Odisha State Pollution Control Board  Industrial Area   2  10   98
#
#           9
# 0     102.0
# 1      96.0
# 2     116.0
# 3     107.0
# 4     118.0
# ...     ...
# 2387   35.0
# 2388   40.0
# 2389   38.0
# 2390   39.0
# 2391   39.0
#
# [2392 rows x 10 columns]
